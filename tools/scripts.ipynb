# %%
import sys
sys.path.append('..')

# %%
import matplotlib.pyplot as plt
import numpy as np
from market import Instruments

# %%
from chart import bar_chart

# %%
df = Instruments.get()[0].to_df(length=100)

# %%
plt.figure(figsize=(12,9))
ax = plt.subplot()
bar_chart(ax, df)
plt.show()

# %%
type(a)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
fig, (ax) = plt.subplot(, figsize=(12,14))
fig.autofmt_xdate()

s= start - 240
ohlc_chart(ax[0], raw_data.iloc[s:end], colors=['k','k'], linewidth=1.44)
#ax[0].axvspan(start, end, facecolor='C1', alpha=0.2)

plt.show()
